# %% [markdown]
# # Volume creation
# Create dev and prod volumes in bronze layer:
# - Data.
# - Checkpoints.
# - Schema.

# %%
# %sql
CREATE VOLUME IF NOT EXISTS capstone_src.dev_bronze.raw_files;
CREATE VOLUME IF NOT EXISTS capstone_src.dev_bronze.checkpoint_files;
CREATE VOLUME IF NOT EXISTS capstone_src.dev_bronze.schema_files;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS capstone_src.prd_bronze.raw_files;
CREATE VOLUME IF NOT EXISTS capstone_src.prd_bronze.checkpoint_files;
CREATE VOLUME IF NOT EXISTS capstone_src.prd_bronze.schema_files;
