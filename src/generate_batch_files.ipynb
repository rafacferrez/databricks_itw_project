# %% [markdown]
# # Generate Batch Files
# Generate files for the batch tables:
# - users.
# - products.
# - sales.
#
# It's possible to set the destination volume and the nnumber of days (files) to be generated.
# By default we will run the exercise for 10 days, and create on capstone_src main repo (instructor).
#
# > NOTE:
# > Running this will overwrite current base data and therefore would affect current users (learners).
# > Consequent tables would need to be updated.

# %%
# %pip install faker

# %% [markdown]
# ## Generate products

# %%
num_days = 10
for env in ["dev", "prd"]:
    base_path = f"/Volumes/capstone_src/{env}_bronze/raw_files/products"
    generate_products(base_path, num_days)

# %% [markdown]
# ## Generate users

# %%
num_days = 10
for env in ["dev", "prd"]:
    base_path = f"/Volumes/capstone_src/{env}_bronze/raw_files/users"
    generate_users(base_path, num_days)

# %% [markdown]
# ## Generate sales

# %%
num_days = 10
for env in ["dev", "prd"]:
    base_path = f"/Volumes/capstone_src/{env}_bronze/raw_files/sales"
    generate_sales(base_path, num_days)
