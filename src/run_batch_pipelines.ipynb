# %% [markdown]
# # Run Batch Pipelines
# Execute batch scripts for an specific environment:
# - Batch Ingestion - Users
# - Batch Ingestion - Products
# - CDC Merge - Sales
# - Gold Layers - Fact Tables / Dimensions

# %%
from instructors.src.solutions.script_manager import ScriptManager

# %%
env = "dev"
sm = ScriptManager(env)

# %% [markdown]
# ## Batch Users

# %%
sm.users_batch_ingestion()

# %% [markdown]
# ## Batch Products

# %%
sm.products_batch_ingestion()

# %% [markdown]
# ## CDC Merge

# %%
sm.sales_cdc_merge()

# %% [markdown]
# ## Gold Layer

# %%
sm.gold_layer()
