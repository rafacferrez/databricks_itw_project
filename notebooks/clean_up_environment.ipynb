# %% [markdown]
# ### ⚠️ Caution: Cleanup Notebook
#
# This notebook is intended to **delete all project resources** — including schemas, volumes, and generated data.
#
# > **Important:** Only run this notebook **after you have finished all exercises and project work**.
# > Running it will **permanently remove** all data and structures in the project environments (`dev` and `prd`).
#
# Use this notebook **at the very end**

# %%
from helpers import setup_schemas, setup_volumes

# %% [markdown]
# ### 🧹 Cleaning up volumes
#
# This cell deletes all **project volumes** in both `dev` and `prd` environments.
#
# The function `clean_up_volumes()`:
#
# - Iterates through all environments (`dev` and `prd`).
# - Drops each volume for the main data entities:
#   - `raw_files`
#   - `checkpoint_files`
#
# > **Warning:** Only run this notebook **after completing the project**, because all raw data stored in these volumes will be permanently removed.

# %%
setup_volumes.clean_up_volumes()

# %% [markdown]
# ### 🧹 Cleaning up schemas
#
# This cell deletes all **project schemas** and their tables in both `dev` and `prd` environments.
#
# The function `clean_up_schemas()`:
#
# - Loops through each environment (`dev` and `prd`).
# - Drops all schemas for every data layer:
#   - `bronze`
#   - `silver`
#   - `gold`
# - Uses `CASCADE` to remove all tables inside the schemas automatically.
#
# > **Warning:** Only run this notebook **after completing the project**, because all data and structures will be permanently removed.

# %%
setup_schemas.clean_up_schemas()
